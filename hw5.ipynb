# %%
# !pip install hyperopt

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter("ignore")
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import FeatureUnion
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
import lightgbm as lgb


from sklearn.metrics import f1_score, roc_auc_score, precision_score, classification_report
from sklearn.metrics import precision_recall_curve, confusion_matrix, mean_squared_error

from hyperopt import fmin, tpe, hp, partial

# %%
def f_score(y_true, y_pred, b=1):
    precision, recall, thresholds = precision_recall_curve(y_true, y_pred)
    fscore = (1 + b ** 2) * (precision * recall) / (b ** 2 * precision + recall)
    r_a_score = roc_auc_score(y_true, y_pred)
    np.nan_to_num(fscore, copy=False)
    # locate the index of the largest f score
    ix = np.argmax(fscore)
    return thresholds[ix], fscore[ix], precision[ix], recall[ix], r_a_score

# %%
#соберем наш простой pipeline, но нам понадобится написать класс для выбора нужного поля
class FeatureSelector(BaseEstimator, TransformerMixin):
    def __init__(self, column):
        self.column = column

    def fit(self, X, y=None):
        return self

    def transform(self, X, y=None):
        return X[self.column]
    
class NumberSelector(BaseEstimator, TransformerMixin):
    """
    Transformer to select a single column from the data frame to perform additional transformations on
    Use on numeric columns in the data
    """
    def __init__(self, key):
        self.key = key

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        return X[[self.key]]
    
class OHEEncoder(BaseEstimator, TransformerMixin):
    def __init__(self, key):
        self.key = key
        self.columns = []

    def fit(self, X, y=None):
        self.columns = [col for col in pd.get_dummies(X, prefix=self.key).columns]
        return self

    def transform(self, X):
        X = pd.get_dummies(X, prefix=self.key)
        test_columns = [col for col in X.columns]
        for col_ in self.columns:
            if col_ not in test_columns:
                X[col_] = 0
        return X[self.columns]

# %% [markdown]
# 1. Для нашего пайплайна (Case1) поэкспериментировать с разными моделями: 1 - бустинг, 2 - логистическая регрессия (не забудьте здесь добавить в cont_transformer стандартизацию - нормирование вещественных признаков)
# 2. Отобрать лучшую модель по метрикам (кстати, какая по вашему мнению здесь наиболее подходящая DS-метрика)
# 3. Для отобранной модели (на отложенной выборке) сделать оценку экономической эффективности при тех же вводных, как в вопросе 2 (1 доллар на привлечение, 2 доллара - с каждого правильно классифицированного (True Positive) удержанного). (подсказка) нужно посчитать FP/TP/FN/TN для выбранного оптимального порога вероятности и посчитать выручку и траты.
# 4. (опционально) Провести подбор гиперпараметров лучшей модели по итогам 2-3
# 5. (опционально) Еще раз провести оценку экономической эффективности

# %%
df = pd.read_csv('churn_data.csv')
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df['Exited'].value_counts(normalize=True)
# Out:
# 0    0.7963
# 1    0.2037
# Name: Exited, dtype: float64

# %%
df.drop(['RowNumber', 'CustomerId', 'Surname'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %% [markdown]
# Разобьем датасет на 3 выборки: трейн, тест и валидационную

# %%
x, X_test, y, y_test = train_test_split(df.drop('Exited', axis=1), df['Exited'], test_size=0.2, train_size=0.8)
X_train, x_cv, y_train, y_cv = train_test_split(x, y, test_size = 0.25, train_size =0.75)

# %%
categorical_columns = ['Geography', 'Gender', 'Tenure', 'HasCrCard', 'IsActiveMember']
continuous_columns = ['CreditScore', 'Age', 'Balance', 'NumOfProducts', 'EstimatedSalary']

# %%
final_transformers = list()

for cat_col in categorical_columns:
    cat_transformer = Pipeline([
                ('selector', FeatureSelector(column=cat_col)),
                ('ohe', OHEEncoder(key=cat_col))
            ])
    final_transformers.append((cat_col, cat_transformer))
    
for cont_col in continuous_columns:
    cont_transformer = Pipeline([
                ('selector', NumberSelector(key=cont_col)),
                ('scaler', StandardScaler()),
            ])
    final_transformers.append((cont_col, cont_transformer))

# %%
feats = FeatureUnion(final_transformers)
feature_processing = Pipeline([('feats', feats)])

# %% [markdown]
# Создадим список пайплайнов с моделями

# %%
model_list = [LogisticRegression, 
              RandomForestClassifier, 
              GradientBoostingClassifier, 
              LGBMClassifier,
              XGBClassifier]
classifier_list = [make_pipeline(feats, model(random_state = 42)) for model in model_list]

# %% [markdown]
# Получим предикты от каждой из них и сведем все в датафрейм

# %%
names = []
metrics = []
for pipe in classifier_list:
    pipe.fit(X_train, y_train)
    y_pred = pipe.predict_proba(X_test)[:, 1]
    names.append(pipe.steps[1][0])
    thr, f1, pr, rec, roc = f_score(y_test.values, y_pred, b=1)
    tn, fp, fn, tp = confusion_matrix(y_test.values, y_pred > thr).ravel()
    metrics.append([thr, f1, pr, rec, roc, tp, tn, fp, fn, fp / (fp + tn)])
# Out:
# [18:22:22] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
m_cols = ['Threshhold', 'F-score', 'Precision', 'Recall', 'ROC-AUC', 'TP', 'TN', 'FP', 'FN', 'FPR']
result_df = pd.DataFrame(metrics, 
                         index=names, 
                         columns=m_cols)
result_df['FPR'] = result_df['FP'] / (result_df['FP'] + result_df['TN'])

# %%
result_df
# Out:
#                             Threshhold   F-score  Precision    Recall  \
# logisticregression            0.307705  0.488208   0.469388  0.508600
# randomforestclassifier        0.410000  0.600277   0.686709  0.533170
# gradientboostingclassifier    0.359124  0.611549   0.656338  0.572482
# lgbmclassifier                0.367175  0.621554   0.634271  0.609337
# xgbclassifier                 0.316108  0.600715   0.583333  0.619165
#
#                              ROC-AUC   TP    TN   FP   FN       FPR
# logisticregression          0.750519  206  1359  234  201  0.146893
# randomforestclassifier      0.834033  211  1499   94  196  0.059008
# gradientboostingclassifier  0.851091  232  1471  122  175  0.076585
# lgbmclassifier              0.851255  247  1450  143  160  0.089768
# xgbclassifier               0.835745  251  1413  180  156  0.112994

# %% [markdown]
# В принципе, все бустинговые модели отработали очень похоже, выберем для теста оптимизации параметров <b>lightgbm</b>

# %% [markdown]
# Оценим работу нашей модели на отложенной выборке

# %%
valid_pred = classifier_list[3].predict_proba(x_cv)[:, 1]

# %%
thr, f1, pr, rec, roc = f_score(y_cv.values, valid_pred, b=1)
tn, fp, fn, tp = confusion_matrix(y_cv.values, valid_pred > thr).ravel()
fpr = fp / (fp + tn)
n_met = [thr, f1, pr, rec, roc, tp, tn, fp, fn, fpr]

# %%
pd.Series({i: j for i, j in zip(m_cols, n_met)}, name='lgbm(on holdout)')
# Out:
# Threshhold       0.416449
# F-score          0.625698
# Precision        0.704403
# Recall           0.562814
# ROC-AUC          0.846188
# TP             223.000000
# TN            1508.000000
# FP              94.000000
# FN             175.000000
# FPR              0.058677
# Name: lgbm(on holdout), dtype: float64

# %% [markdown]
# Посчитаем следующим образом:
#
# Деньги мы тратим на удержание клиентов, которые, как мы считаем, уходят. То есть это TN и FN. Но с FN мы получаем деньги, так как они на самом деле не уходят.
#
# На TP мы ничего не тратим, они приносят нам деньги
# На FP мы также ничего не тратим, так как считаем что они не уходят - деньги они не приносят
# На TN мы тратим деньги на удержание

# %%
hold = -1
true_p = 2

tp * true_p + fp * 0 + (fn * hold + fn * true_p) + tn * hold
# Out:
# -887

# %% [markdown]
# Модель не целесообразна экономически

# %% [markdown]
# Попробуем оптимизировать.
#
# Код, с небольшими модификациями, <a href='https://www.programmersought.com/article/81271625281/'>отсюда</a>

# %%
x_tr, x_te, y_tr, y_te = train_test_split(feature_processing.fit_transform(df.drop(['Exited'], 
                                                                                   axis=1)), 
                                          df['Exited'], test_size=0.3, random_state=0)

# %%
train_data = lgb.Dataset(data=x_tr,label=y_tr)
test_data = lgb.Dataset(data=x_te,label=y_te)

# %%
# Customize the parameter space of hyperopt
space = {"max_depth": hp.randint("max_depth", 15),
         "num_trees": hp.randint("num_trees", 300),
         'learning_rate': hp.uniform('learning_rate', 1e-3, 5e-1),
         "bagging_fraction": hp.randint("bagging_fraction", 5),
         "num_leaves": hp.randint("num_leaves", 6),
         }
 
def argsDict_tranform(argsDict, isPrint=False):
    argsDict["max_depth"] = argsDict["max_depth"] + 5
    argsDict['num_trees'] = argsDict['num_trees'] + 150
    argsDict["learning_rate"] = argsDict["learning_rate"] * 0.02 + 0.05
    argsDict["bagging_fraction"] = argsDict["bagging_fraction"] * 0.1 + 0.5
    argsDict["num_leaves"] = argsDict["num_leaves"] * 3 + 10
    if isPrint:
        print(argsDict)
    else:
        pass
 
    return argsDict

# %%
def lightgbm_factory(argsDict):
    argsDict = argsDict_tranform(argsDict)
 
    params = {'nthread': -1, # number of processes
                     'max_depth': argsDict['max_depth'], # maximum depth
                     'num_trees': argsDict['num_trees'], # number of trees
                     'eta': argsDict['learning_rate'], # learning rate
                     'bagging_fraction': argsDict['bagging_fraction'], # baggingsamples
                     'num_leaves': argsDict['num_leaves'], # The sum of the smallest sample of the endpoints
                     'objective': 'regression',
                     'feature_fraction': 0.7, #sample column sampling
                     'lambda_l1': 0, # L1 regularization
                     'lambda_l2': 0, # L2 Regularization
                     'bagging_seed': 100, # random seed, default in light 100
              }
    #rmse
    params['metric'] = ['rmse']
 
    model_lgb = lgb.train(params, train_data, num_boost_round=300, valid_sets=[test_data],early_stopping_rounds=100)
 
    return get_tranformer_score(model_lgb)
 
def get_tranformer_score(tranformer):
 
    model = tranformer
    prediction = model.predict(x_te, num_iteration=model.best_iteration)
 
    return mean_squared_error(y_te, prediction)

# %%
#Start using hyperopt for automatic parameter adjustment
algo = partial(tpe.suggest, n_startup_jobs=1)
best = fmin(lightgbm_factory, space, algo=algo, max_evals=20, pass_expr_memo_ctrl=None)
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000377 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 874
# [LightGBM] [Info] Number of data points in the train set: 7000, number of used features: 25
# [LightGBM] [Info] Start training from score 0.202286
# [1]	valid_0's rmse: 0.400007
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's rmse: 0.395327
# [3]	valid_0's rmse: 0.391478
# [4]	valid_0's rmse: 0.38577
# [5]	valid_0's rmse: 0.379858
# [6]	valid_0's rmse: 0.376827
# [7]	valid_0's rmse: 0.373153
# [8]	valid_0's rmse: 0.368273
# [9]	valid_0's rmse: 0.365268
# [10]	valid_0's rmse: 0.361142
# [11]	valid_0's rmse: 0.358533
# [12]	valid_0's rmse: 0.354987
# [13]	valid_0's rmse: 0.352963
# [14]	valid_0's rmse: 0.349933
# [15]	valid_0's rmse: 0.34775
# [16]	valid_0's rmse: 0.345239
# [17]	valid_0's rmse: 0.343377
# [18]	valid_0's rmse: 0.342859
# [19]	valid_0's rmse: 0.341201
# [20]	valid_0's rmse: 0.340047
# [21]	valid_0's rmse: 0.338043
# [22]	valid_0's rmse: 0.336677
# [23]	valid_0's rmse: 0.334862
# [24]	valid_0's rmse: 0.33373
# [25]	valid_0's rmse: 0.332252
# [26]	valid_0's rmse: 0.330811
# [27]	valid_0's rmse: 0.330515
# [28]	valid_0's rmse: 0.329234
# [29]	valid_0's rmse: 0.328119
# [30]	valid_0's rmse: 0.327277
# [31]	valid_0's rmse: 0.326316
# [32]	valid_0's rmse: 0.325299
# [33]	valid_0's rmse: 0.324686
# [34]	valid_0's rmse: 0.324329
# [35]	valid_0's rmse: 0.323592
# [36]	valid_0's rmse: 0.32297
# [37]	valid_0's rmse: 0.322305
# [38]	valid_0's rmse: 0.321898
# [39]	valid_0's rmse: 0.321575
# [40]	valid_0's rmse: 0.321154
# [41]	valid_0's rmse: 0.320592
# [42]	valid_0's rmse: 0.320393
# [43]	valid_0's rmse: 0.319915
# [44]	valid_0's rmse: 0.31963
# [45]	valid_0's rmse: 0.319265
# [46]	valid_0's rmse: 0.319004
# [47]	valid_0's rmse: 0.318669
# [48]	valid_0's rmse: 0.318386
# [49]	valid_0's rmse: 0.318151
# [50]	valid_0's rmse: 0.31788
# [51]	valid_0's rmse: 0.317713
# [52]	valid_0's rmse: 0.317546
# [53]	valid_0's rmse: 0.317322
# [54]	valid_0's rmse: 0.317188
# [55]	valid_0's rmse: 0.317029
# [56]	valid_0's rmse: 0.316829
# [57]	valid_0's rmse: 0.316629
# [58]	valid_0's rmse: 0.316451
# [59]	valid_0's rmse: 0.316342
# [60]	valid_0's rmse: 0.31623
# [61]	valid_0's rmse: 0.316077
# [62]	valid_0's rmse: 0.315902
# [63]	valid_0's rmse: 0.31587
# [64]	valid_0's rmse: 0.315854
# [65]	valid_0's rmse: 0.315806
# [66]	valid_0's rmse: 0.315766
# [67]	valid_0's rmse: 0.315664
# [68]	valid_0's rmse: 0.315526
# [69]	valid_0's rmse: 0.315416
# [70]	valid_0's rmse: 0.315329
# [71]	valid_0's rmse: 0.315133
# [72]	valid_0's rmse: 0.315049
# [73]	valid_0's rmse: 0.315095
# [74]	valid_0's rmse: 0.314982
# [75]	valid_0's rmse: 0.31491
# [76]	valid_0's rmse: 0.314799
# [77]	valid_0's rmse: 0.314746
# [78]	valid_0's rmse: 0.31473
# [79]	valid_0's rmse: 0.314596
# [80]	valid_0's rmse: 0.31448
# [81]	valid_0's rmse: 0.314486
# [82]	valid_0's rmse: 0.314406
# [83]	valid_0's rmse: 0.314386
# [84]	valid_0's rmse: 0.314332
# [85]	valid_0's rmse: 0.314272
# [86]	valid_0's rmse: 0.314247
# [87]	valid_0's rmse: 0.314242
# [88]	valid_0's rmse: 0.31428
# [89]	valid_0's rmse: 0.314212
# [90]	valid_0's rmse: 0.314206
# [91]	valid_0's rmse: 0.314175
# [92]	valid_0's rmse: 0.314197
# [93]	valid_0's rmse: 0.31408
# [94]	valid_0's rmse: 0.314098
# [95]	valid_0's rmse: 0.314091
# [96]	valid_0's rmse: 0.314102
# [97]	valid_0's rmse: 0.314154
# [98]	valid_0's rmse: 0.314137
# [99]	valid_0's rmse: 0.314121
# [100]	valid_0's rmse: 0.314088
# [101]	valid_0's rmse: 0.314106
# [102]	valid_0's rmse: 0.314119
# [103]	valid_0's rmse: 0.314155
# [104]	valid_0's rmse: 0.314141
# [105]	valid_0's rmse: 0.314131
# [106]	valid_0's rmse: 0.314148
# [107]	valid_0's rmse: 0.314109
# [108]	valid_0's rmse: 0.314159
# [109]	valid_0's rmse: 0.314172
# [110]	valid_0's rmse: 0.314161
# [111]	valid_0's rmse: 0.314285
# [112]	valid_0's rmse: 0.314327
# [113]	valid_0's rmse: 0.31436
# [114]	valid_0's rmse: 0.314375
# [115]	valid_0's rmse: 0.314338
# [116]	valid_0's rmse: 0.314321
# [117]	valid_0's rmse: 0.314397
# [118]	valid_0's rmse: 0.314382
# [119]	valid_0's rmse: 0.314427
# [120]	valid_0's rmse: 0.314368
# [121]	valid_0's rmse: 0.31432
# [122]	valid_0's rmse: 0.314297
# [123]	valid_0's rmse: 0.314254
# [124]	valid_0's rmse: 0.314261
# [125]	valid_0's rmse: 0.314311
# [126]	valid_0's rmse: 0.314276
# [127]	valid_0's rmse: 0.314279
# [128]	valid_0's rmse: 0.314272
# [129]	valid_0's rmse: 0.314297
# [130]	valid_0's rmse: 0.31431
# [131]	valid_0's rmse: 0.314304
# [132]	valid_0's rmse: 0.314318
# [133]	valid_0's rmse: 0.314308
# [134]	valid_0's rmse: 0.314312
# [135]	valid_0's rmse: 0.314347
# [136]	valid_0's rmse: 0.314378
# [137]	valid_0's rmse: 0.314403
# [138]	valid_0's rmse: 0.314407
# [139]	valid_0's rmse: 0.314395
# [140]	valid_0's rmse: 0.314444
# [141]	valid_0's rmse: 0.314474
# [142]	valid_0's rmse: 0.314446
# [143]	valid_0's rmse: 0.314459
# [144]	valid_0's rmse: 0.314484
# [145]	valid_0's rmse: 0.314529
# [146]	valid_0's rmse: 0.314563
# [147]	valid_0's rmse: 0.314561
# [148]	valid_0's rmse: 0.314563
# [149]	valid_0's rmse: 0.314583
# [150]	valid_0's rmse: 0.314618
# [151]	valid_0's rmse: 0.314603
# [152]	valid_0's rmse: 0.314579
# [153]	valid_0's rmse: 0.314574
# [154]	valid_0's rmse: 0.314533
# [155]	valid_0's rmse: 0.314524
# [156]	valid_0's rmse: 0.314518
# [157]	valid_0's rmse: 0.314448
# [158]	valid_0's rmse: 0.314433
# [159]	valid_0's rmse: 0.314443
# [160]	valid_0's rmse: 0.314425
# [161]	valid_0's rmse: 0.314417
# [162]	valid_0's rmse: 0.314399
# [163]	valid_0's rmse: 0.314414
# [164]	valid_0's rmse: 0.314432
# [165]	valid_0's rmse: 0.314436
# [166]	valid_0's rmse: 0.314435
# [167]	valid_0's rmse: 0.314418
# [168]	valid_0's rmse: 0.314415
# [169]	valid_0's rmse: 0.314416
# [170]	valid_0's rmse: 0.31447
# [171]	valid_0's rmse: 0.314434
# [172]	valid_0's rmse: 0.314454
# [173]	valid_0's rmse: 0.31448
# [174]	valid_0's rmse: 0.314487
# [175]	valid_0's rmse: 0.314475
# [176]	valid_0's rmse: 0.314502
# [177]	valid_0's rmse: 0.31454
# [178]	valid_0's rmse: 0.314557
# [179]	valid_0's rmse: 0.314558
# [180]	valid_0's rmse: 0.314548
# [181]	valid_0's rmse: 0.314543
# [182]	valid_0's rmse: 0.314597
# [183]	valid_0's rmse: 0.314599
# [184]	valid_0's rmse: 0.314656
# [185]	valid_0's rmse: 0.314596
# [186]	valid_0's rmse: 0.314586
# [187]	valid_0's rmse: 0.3146
# [188]	valid_0's rmse: 0.314595
# [189]	valid_0's rmse: 0.314591
# [190]	valid_0's rmse: 0.31461
# [191]	valid_0's rmse: 0.314643
# [192]	valid_0's rmse: 0.314648
# [193]	valid_0's rmse: 0.314639
# Early stopping, best iteration is:
# [93]	valid_0's rmse: 0.31408
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000359 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 874
# [LightGBM] [Info] Number of data points in the train set: 7000, number of used features: 25
# [LightGBM] [Info] Start training from score 0.202286
# [1]	valid_0's rmse: 0.400097
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's rmse: 0.395497
# [3]	valid_0's rmse: 0.391707
# [4]	valid_0's rmse: 0.386041
# [5]	valid_0's rmse: 0.380201
# [6]	valid_0's rmse: 0.377199
# [7]	valid_0's rmse: 0.373555
# [8]	valid_0's rmse: 0.36865
# [9]	valid_0's rmse: 0.365662
# [10]	valid_0's rmse: 0.361551
# [11]	valid_0's rmse: 0.358957
# [12]	valid_0's rmse: 0.355397
# [13]	valid_0's rmse: 0.353384
# [14]	valid_0's rmse: 0.350349
# [15]	valid_0's rmse: 0.348177
# [16]	valid_0's rmse: 0.345702
# [17]	valid_0's rmse: 0.343854
# [18]	valid_0's rmse: 0.343352
# [19]	valid_0's rmse: 0.3416
# [20]	valid_0's rmse: 0.340446
# [21]	valid_0's rmse: 0.338349
# [22]	valid_0's rmse: 0.336982
# [23]	valid_0's rmse: 0.335288
# [24]	valid_0's rmse: 0.334083
# [25]	valid_0's rmse: 0.332614
# [26]	valid_0's rmse: 0.331164
# [27]	valid_0's rmse: 0.330846
# [28]	valid_0's rmse: 0.329563
# [29]	valid_0's rmse: 0.328433
# [30]	valid_0's rmse: 0.327639
# [31]	valid_0's rmse: 0.326627
# [32]	valid_0's rmse: 0.325746
# [33]	valid_0's rmse: 0.325129
# [34]	valid_0's rmse: 0.324747
# [35]	valid_0's rmse: 0.32397
# [36]	valid_0's rmse: 0.323314
# [37]	valid_0's rmse: 0.322765
# [38]	valid_0's rmse: 0.322233
# [39]	valid_0's rmse: 0.32197
# [40]	valid_0's rmse: 0.321591
# [41]	valid_0's rmse: 0.321061
# [42]	valid_0's rmse: 0.320875
# [43]	valid_0's rmse: 0.320378
# [44]	valid_0's rmse: 0.320007
# [45]	valid_0's rmse: 0.31963
# [46]	valid_0's rmse: 0.319294
# [47]	valid_0's rmse: 0.31906
# [48]	valid_0's rmse: 0.318631
# [49]	valid_0's rmse: 0.318386
# [50]	valid_0's rmse: 0.318174
# [51]	valid_0's rmse: 0.318035
# [52]	valid_0's rmse: 0.317939
# [53]	valid_0's rmse: 0.317764
# [54]	valid_0's rmse: 0.317602
# [55]	valid_0's rmse: 0.317411
# [56]	valid_0's rmse: 0.31731
# [57]	valid_0's rmse: 0.317073
# [58]	valid_0's rmse: 0.316949
# [59]	valid_0's rmse: 0.316749
# [60]	valid_0's rmse: 0.316591
# [61]	valid_0's rmse: 0.316523
# [62]	valid_0's rmse: 0.316424
# [63]	valid_0's rmse: 0.316357
# [64]	valid_0's rmse: 0.316321
# [65]	valid_0's rmse: 0.316248
# [66]	valid_0's rmse: 0.316171
# [67]	valid_0's rmse: 0.316139
# [68]	valid_0's rmse: 0.316064
# [69]	valid_0's rmse: 0.315992
# [70]	valid_0's rmse: 0.31585
# [71]	valid_0's rmse: 0.315744
# [72]	valid_0's rmse: 0.315648
# [73]	valid_0's rmse: 0.315542
# [74]	valid_0's rmse: 0.315476
# [75]	valid_0's rmse: 0.315483
# [76]	valid_0's rmse: 0.315411
# [77]	valid_0's rmse: 0.315262
# [78]	valid_0's rmse: 0.315203
# [79]	valid_0's rmse: 0.315196
# [80]	valid_0's rmse: 0.315027
# [81]	valid_0's rmse: 0.315004
# [82]	valid_0's rmse: 0.31494
# [83]	valid_0's rmse: 0.314931
# [84]	valid_0's rmse: 0.314896
# [85]	valid_0's rmse: 0.314879
# [86]	valid_0's rmse: 0.314905
# [87]	valid_0's rmse: 0.31493
# [88]	valid_0's rmse: 0.314886
# [89]	valid_0's rmse: 0.314836
# [90]	valid_0's rmse: 0.314826
# [91]	valid_0's rmse: 0.314822
# [92]	valid_0's rmse: 0.314847
# [93]	valid_0's rmse: 0.314746
# [94]	valid_0's rmse: 0.314813
# [95]	valid_0's rmse: 0.314734
# [96]	valid_0's rmse: 0.314776
# [97]	valid_0's rmse: 0.314794
# [98]	valid_0's rmse: 0.31479
# [99]	valid_0's rmse: 0.314779
# [100]	valid_0's rmse: 0.314772
# [101]	valid_0's rmse: 0.314863
# [102]	valid_0's rmse: 0.314805
# [103]	valid_0's rmse: 0.31476
# [104]	valid_0's rmse: 0.314763
# [105]	valid_0's rmse: 0.314737
# [106]	valid_0's rmse: 0.314786
# [107]	valid_0's rmse: 0.314795
# [108]	valid_0's rmse: 0.314859
# [109]	valid_0's rmse: 0.314854
# [110]	valid_0's rmse: 0.314833
# [111]	valid_0's rmse: 0.314842
# [112]	valid_0's rmse: 0.314876
# [113]	valid_0's rmse: 0.314837
# [114]	valid_0's rmse: 0.314846
# [115]	valid_0's rmse: 0.314831
# [116]	valid_0's rmse: 0.314832
# [117]	valid_0's rmse: 0.314808
# [118]	valid_0's rmse: 0.314835
# [119]	valid_0's rmse: 0.314777
# [120]	valid_0's rmse: 0.314779
# [121]	valid_0's rmse: 0.314807
# [122]	valid_0's rmse: 0.314857
# [123]	valid_0's rmse: 0.314855
# [124]	valid_0's rmse: 0.314865
# [125]	valid_0's rmse: 0.314798
# [126]	valid_0's rmse: 0.314796
# [127]	valid_0's rmse: 0.31479
# [128]	valid_0's rmse: 0.314854
# [129]	valid_0's rmse: 0.314826
# [130]	valid_0's rmse: 0.31482
# [131]	valid_0's rmse: 0.314848
# [132]	valid_0's rmse: 0.314834
# [133]	valid_0's rmse: 0.314863
# [134]	valid_0's rmse: 0.314866
# [135]	valid_0's rmse: 0.314853
# [136]	valid_0's rmse: 0.314878
# [137]	valid_0's rmse: 0.314878
# [138]	valid_0's rmse: 0.314926
# [139]	valid_0's rmse: 0.314986
# [140]	valid_0's rmse: 0.315041
# [141]	valid_0's rmse: 0.315045
# [142]	valid_0's rmse: 0.315065
# [143]	valid_0's rmse: 0.315074
# [144]	valid_0's rmse: 0.315101
# [145]	valid_0's rmse: 0.315079
# [146]	valid_0's rmse: 0.315076
# [147]	valid_0's rmse: 0.315003
# [148]	valid_0's rmse: 0.314947
# [149]	valid_0's rmse: 0.314992
# [150]	valid_0's rmse: 0.315011
# [151]	valid_0's rmse: 0.315016
# [152]	valid_0's rmse: 0.315015
# [153]	valid_0's rmse: 0.314997
# [154]	valid_0's rmse: 0.314932
# [155]	valid_0's rmse: 0.314921
# [156]	valid_0's rmse: 0.314984
# [157]	valid_0's rmse: 0.315001
# [158]	valid_0's rmse: 0.31515
# [159]	valid_0's rmse: 0.315185
# [160]	valid_0's rmse: 0.315169
# [161]	valid_0's rmse: 0.315176
# [162]	valid_0's rmse: 0.315188
# [163]	valid_0's rmse: 0.315201
# [164]	valid_0's rmse: 0.31523
# [165]	valid_0's rmse: 0.315246
# [166]	valid_0's rmse: 0.315255
# [167]	valid_0's rmse: 0.315263
# [168]	valid_0's rmse: 0.315347
# [169]	valid_0's rmse: 0.315339
# [170]	valid_0's rmse: 0.315358
# [171]	valid_0's rmse: 0.315347
# [172]	valid_0's rmse: 0.315363
# [173]	valid_0's rmse: 0.315333
# [174]	valid_0's rmse: 0.315386
# [175]	valid_0's rmse: 0.315377
# [176]	valid_0's rmse: 0.315363
# [177]	valid_0's rmse: 0.315428
# [178]	valid_0's rmse: 0.315432
# [179]	valid_0's rmse: 0.315426
# [180]	valid_0's rmse: 0.315433
# [181]	valid_0's rmse: 0.315447
# [182]	valid_0's rmse: 0.315464
# [183]	valid_0's rmse: 0.315477
# [184]	valid_0's rmse: 0.315428
# [185]	valid_0's rmse: 0.31547
# [186]	valid_0's rmse: 0.315449
# [187]	valid_0's rmse: 0.315438
# [188]	valid_0's rmse: 0.315433
# [189]	valid_0's rmse: 0.315403
# [190]	valid_0's rmse: 0.315414
# [191]	valid_0's rmse: 0.315419
# [192]	valid_0's rmse: 0.315431
# [193]	valid_0's rmse: 0.315425
# [194]	valid_0's rmse: 0.315481
# [195]	valid_0's rmse: 0.315503
# Early stopping, best iteration is:
# [95]	valid_0's rmse: 0.314734
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000385 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 874
# [LightGBM] [Info] Number of data points in the train set: 7000, number of used features: 25
# [LightGBM] [Info] Start training from score 0.202286
# [1]	valid_0's rmse: 0.399284
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's rmse: 0.393893
# [3]	valid_0's rmse: 0.38958
# [4]	valid_0's rmse: 0.383093
# [5]	valid_0's rmse: 0.376441
# [6]	valid_0's rmse: 0.373123
# [7]	valid_0's rmse: 0.369083
# [8]	valid_0's rmse: 0.363837
# [9]	valid_0's rmse: 0.36064
# [10]	valid_0's rmse: 0.356148
# [11]	valid_0's rmse: 0.353428
# [12]	valid_0's rmse: 0.349631
# [13]	valid_0's rmse: 0.347632
# [14]	valid_0's rmse: 0.344699
# [15]	valid_0's rmse: 0.342592
# [16]	valid_0's rmse: 0.34005
# [17]	valid_0's rmse: 0.338373
# [18]	valid_0's rmse: 0.337814
# [19]	valid_0's rmse: 0.336256
# [20]	valid_0's rmse: 0.335185
# [21]	valid_0's rmse: 0.333198
# [22]	valid_0's rmse: 0.331979
# [23]	valid_0's rmse: 0.330308
# [24]	valid_0's rmse: 0.329239
# [25]	valid_0's rmse: 0.327796
# [26]	valid_0's rmse: 0.326635
# [27]	valid_0's rmse: 0.326409
# [28]	valid_0's rmse: 0.325312
# [29]	valid_0's rmse: 0.324328
# [30]	valid_0's rmse: 0.323617
# [31]	valid_0's rmse: 0.322741
# [32]	valid_0's rmse: 0.321994
# [33]	valid_0's rmse: 0.321515
# [34]	valid_0's rmse: 0.321378
# [35]	valid_0's rmse: 0.320808
# [36]	valid_0's rmse: 0.320267
# [37]	valid_0's rmse: 0.319702
# [38]	valid_0's rmse: 0.319346
# [39]	valid_0's rmse: 0.319092
# [40]	valid_0's rmse: 0.31887
# [41]	valid_0's rmse: 0.318501
# [42]	valid_0's rmse: 0.318364
# [43]	valid_0's rmse: 0.318077
# [44]	valid_0's rmse: 0.317781
# [45]	valid_0's rmse: 0.317535
# [46]	valid_0's rmse: 0.317365
# [47]	valid_0's rmse: 0.317247
# [48]	valid_0's rmse: 0.317107
# [49]	valid_0's rmse: 0.31687
# [50]	valid_0's rmse: 0.316643
# [51]	valid_0's rmse: 0.316538
# [52]	valid_0's rmse: 0.316445
# [53]	valid_0's rmse: 0.316284
# [54]	valid_0's rmse: 0.316146
# [55]	valid_0's rmse: 0.316037
# [56]	valid_0's rmse: 0.315944
# [57]	valid_0's rmse: 0.315913
# [58]	valid_0's rmse: 0.315892
# [59]	valid_0's rmse: 0.315792
# [60]	valid_0's rmse: 0.315774
# [61]	valid_0's rmse: 0.315686
# [62]	valid_0's rmse: 0.315614
# [63]	valid_0's rmse: 0.315587
# [64]	valid_0's rmse: 0.31555
# [65]	valid_0's rmse: 0.315548
# [66]	valid_0's rmse: 0.315566
# [67]	valid_0's rmse: 0.315422
# [68]	valid_0's rmse: 0.315384
# [69]	valid_0's rmse: 0.315342
# [70]	valid_0's rmse: 0.315277
# [71]	valid_0's rmse: 0.315168
# [72]	valid_0's rmse: 0.315153
# [73]	valid_0's rmse: 0.315161
# [74]	valid_0's rmse: 0.315054
# [75]	valid_0's rmse: 0.315045
# [76]	valid_0's rmse: 0.314962
# [77]	valid_0's rmse: 0.314998
# [78]	valid_0's rmse: 0.314935
# [79]	valid_0's rmse: 0.314907
# [80]	valid_0's rmse: 0.314855
# [81]	valid_0's rmse: 0.314857
# [82]	valid_0's rmse: 0.314918
# [83]	valid_0's rmse: 0.314878
# [84]	valid_0's rmse: 0.314839
# [85]	valid_0's rmse: 0.314803
# [86]	valid_0's rmse: 0.314882
# [87]	valid_0's rmse: 0.314894
# [88]	valid_0's rmse: 0.314945
# [89]	valid_0's rmse: 0.314939
# [90]	valid_0's rmse: 0.314896
# [91]	valid_0's rmse: 0.31493
# [92]	valid_0's rmse: 0.31494
# [93]	valid_0's rmse: 0.314944
# [94]	valid_0's rmse: 0.314843
# [95]	valid_0's rmse: 0.314837
# [96]	valid_0's rmse: 0.314846
# [97]	valid_0's rmse: 0.314813
# [98]	valid_0's rmse: 0.314812
# [99]	valid_0's rmse: 0.314862
# [100]	valid_0's rmse: 0.314886
# [101]	valid_0's rmse: 0.314831
# [102]	valid_0's rmse: 0.314841
# [103]	valid_0's rmse: 0.314888
# [104]	valid_0's rmse: 0.31492
# [105]	valid_0's rmse: 0.314911
# [106]	valid_0's rmse: 0.315015
# [107]	valid_0's rmse: 0.315014
# [108]	valid_0's rmse: 0.315068
# [109]	valid_0's rmse: 0.31509
# [110]	valid_0's rmse: 0.315095
# [111]	valid_0's rmse: 0.315103
# [112]	valid_0's rmse: 0.315046
# [113]	valid_0's rmse: 0.315038
# [114]	valid_0's rmse: 0.315005
# [115]	valid_0's rmse: 0.314996
# [116]	valid_0's rmse: 0.315014
# [117]	valid_0's rmse: 0.314962
# [118]	valid_0's rmse: 0.314977
# [119]	valid_0's rmse: 0.314978
# [120]	valid_0's rmse: 0.314956
# [121]	valid_0's rmse: 0.315006
# [122]	valid_0's rmse: 0.314967
# [123]	valid_0's rmse: 0.314983
# [124]	valid_0's rmse: 0.315059
# [125]	valid_0's rmse: 0.315131
# [126]	valid_0's rmse: 0.315148
# [127]	valid_0's rmse: 0.315171
# [128]	valid_0's rmse: 0.315184
# [129]	valid_0's rmse: 0.315193
# [130]	valid_0's rmse: 0.315176
# [131]	valid_0's rmse: 0.315155
# [132]	valid_0's rmse: 0.315185
# [133]	valid_0's rmse: 0.315191
# [134]	valid_0's rmse: 0.31526
# [135]	valid_0's rmse: 0.31533
# [136]	valid_0's rmse: 0.315314
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [137]	valid_0's rmse: 0.315347
# [138]	valid_0's rmse: 0.315344
# [139]	valid_0's rmse: 0.315389
# [140]	valid_0's rmse: 0.315481
# [141]	valid_0's rmse: 0.315526
# [142]	valid_0's rmse: 0.315572
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [143]	valid_0's rmse: 0.315592
# [144]	valid_0's rmse: 0.315612
# [145]	valid_0's rmse: 0.315609
# [146]	valid_0's rmse: 0.315621
# [147]	valid_0's rmse: 0.315595
# [148]	valid_0's rmse: 0.315674
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [149]	valid_0's rmse: 0.315653
# [150]	valid_0's rmse: 0.315672
# [151]	valid_0's rmse: 0.315703
# [152]	valid_0's rmse: 0.31571
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [153]	valid_0's rmse: 0.31574
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [154]	valid_0's rmse: 0.315741
# [155]	valid_0's rmse: 0.315708
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [156]	valid_0's rmse: 0.315717
# [157]	valid_0's rmse: 0.315724
# [158]	valid_0's rmse: 0.315785
# [159]	valid_0's rmse: 0.315823
# [160]	valid_0's rmse: 0.315786
# [161]	valid_0's rmse: 0.31576
# [162]	valid_0's rmse: 0.31578
# [163]	valid_0's rmse: 0.31576
# [164]	valid_0's rmse: 0.315754
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [165]	valid_0's rmse: 0.31576
# [166]	valid_0's rmse: 0.315752
# [167]	valid_0's rmse: 0.315792
# [168]	valid_0's rmse: 0.315821
# [169]	valid_0's rmse: 0.315854
# [170]	valid_0's rmse: 0.315871
# [171]	valid_0's rmse: 0.315889
# [172]	valid_0's rmse: 0.315886
# [173]	valid_0's rmse: 0.315953
# [174]	valid_0's rmse: 0.315976
# [175]	valid_0's rmse: 0.316003
# [176]	valid_0's rmse: 0.315971
# [177]	valid_0's rmse: 0.316008
# [178]	valid_0's rmse: 0.315994
# [179]	valid_0's rmse: 0.316077
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [180]	valid_0's rmse: 0.316083
# [181]	valid_0's rmse: 0.316052
# [182]	valid_0's rmse: 0.316068
# [183]	valid_0's rmse: 0.316096
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [184]	valid_0's rmse: 0.316099
# [185]	valid_0's rmse: 0.316114
# Early stopping, best iteration is:
# [85]	valid_0's rmse: 0.314803
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000298 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 874
# [LightGBM] [Info] Number of data points in the train set: 7000, number of used features: 25
# [LightGBM] [Info] Start training from score 0.202286
# [1]	valid_0's rmse: 0.400134
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's rmse: 0.39552
# [3]	valid_0's rmse: 0.39173
# [4]	valid_0's rmse: 0.386176
# [5]	valid_0's rmse: 0.380358
# [6]	valid_0's rmse: 0.377366
# [7]	valid_0's rmse: 0.37374
# [8]	valid_0's rmse: 0.36886
# [9]	valid_0's rmse: 0.365869
# [10]	valid_0's rmse: 0.36177
# [11]	valid_0's rmse: 0.359228
# [12]	valid_0's rmse: 0.355721
# [13]	valid_0's rmse: 0.353652
# [14]	valid_0's rmse: 0.350612
# [15]	valid_0's rmse: 0.348386
# [16]	valid_0's rmse: 0.345879
# [17]	valid_0's rmse: 0.34402
# [18]	valid_0's rmse: 0.343468
# [19]	valid_0's rmse: 0.341797
# [20]	valid_0's rmse: 0.340621
# [21]	valid_0's rmse: 0.338542
# [22]	valid_0's rmse: 0.337173
# [23]	valid_0's rmse: 0.335435
# [24]	valid_0's rmse: 0.33414
# [25]	valid_0's rmse: 0.332614
# [26]	valid_0's rmse: 0.331211
# [27]	valid_0's rmse: 0.330895
# [28]	valid_0's rmse: 0.329577
# [29]	valid_0's rmse: 0.328509
# [30]	valid_0's rmse: 0.327732
# [31]	valid_0's rmse: 0.326707
# [32]	valid_0's rmse: 0.325836
# [33]	valid_0's rmse: 0.32517
# [34]	valid_0's rmse: 0.324801
# [35]	valid_0's rmse: 0.323963
# [36]	valid_0's rmse: 0.323191
# [37]	valid_0's rmse: 0.322621
# [38]	valid_0's rmse: 0.322095
# [39]	valid_0's rmse: 0.321781
# [40]	valid_0's rmse: 0.321363
# [41]	valid_0's rmse: 0.320834
# ...
# [41]	valid_0's rmse: 0.319837
# [42]	valid_0's rmse: 0.319621
# [43]	valid_0's rmse: 0.319214
# [44]	valid_0's rmse: 0.318906
# [45]	valid_0's rmse: 0.318587
# [46]	valid_0's rmse: 0.318412
# [47]	valid_0's rmse: 0.318089
# [48]	valid_0's rmse: 0.317798
# [49]	valid_0's rmse: 0.317665
# [50]	valid_0's rmse: 0.31753
# [51]	valid_0's rmse: 0.317429
# [52]	valid_0's rmse: 0.317205
# [53]	valid_0's rmse: 0.316967
# [54]	valid_0's rmse: 0.316755
# [55]	valid_0's rmse: 0.316628
# [56]	valid_0's rmse: 0.316578
# [57]	valid_0's rmse: 0.31642
# [58]	valid_0's rmse: 0.316375
# [59]	valid_0's rmse: 0.316241
# [60]	valid_0's rmse: 0.316202
# [61]	valid_0's rmse: 0.316025
# [62]	valid_0's rmse: 0.316001
# [63]	valid_0's rmse: 0.31597
# [64]	valid_0's rmse: 0.316001
# [65]	valid_0's rmse: 0.315908
# [66]	valid_0's rmse: 0.315819
# [67]	valid_0's rmse: 0.315584
# [68]	valid_0's rmse: 0.315501
# [69]	valid_0's rmse: 0.315364
# [70]	valid_0's rmse: 0.315194
# [71]	valid_0's rmse: 0.315166
# [72]	valid_0's rmse: 0.315068
# [73]	valid_0's rmse: 0.314989
# [74]	valid_0's rmse: 0.314864
# [75]	valid_0's rmse: 0.314869
# [76]	valid_0's rmse: 0.314854
# [77]	valid_0's rmse: 0.314953
# [78]	valid_0's rmse: 0.314839
# [79]	valid_0's rmse: 0.314706
# [80]	valid_0's rmse: 0.314658
# [81]	valid_0's rmse: 0.314654
# [82]	valid_0's rmse: 0.31466
# [83]	valid_0's rmse: 0.31464
# [84]	valid_0's rmse: 0.314595
# [85]	valid_0's rmse: 0.314585
# [86]	valid_0's rmse: 0.314586
# [87]	valid_0's rmse: 0.314545
# [88]	valid_0's rmse: 0.314514
# [89]	valid_0's rmse: 0.3145
# [90]	valid_0's rmse: 0.31454
# [91]	valid_0's rmse: 0.314498
# [92]	valid_0's rmse: 0.314536
# [93]	valid_0's rmse: 0.314524
# [94]	valid_0's rmse: 0.314559
# [95]	valid_0's rmse: 0.314559
# [96]	valid_0's rmse: 0.314416
# [97]	valid_0's rmse: 0.314403
# [98]	valid_0's rmse: 0.31441
# [99]	valid_0's rmse: 0.314458
# [100]	valid_0's rmse: 0.314366
# [101]	valid_0's rmse: 0.314347
# [102]	valid_0's rmse: 0.314327
# [103]	valid_0's rmse: 0.314359
# [104]	valid_0's rmse: 0.314344
# [105]	valid_0's rmse: 0.314335
# [106]	valid_0's rmse: 0.31435
# [107]	valid_0's rmse: 0.31438
# [108]	valid_0's rmse: 0.314373
# [109]	valid_0's rmse: 0.314368
# [110]	valid_0's rmse: 0.314379
# [111]	valid_0's rmse: 0.314431
# [112]	valid_0's rmse: 0.314425
# [113]	valid_0's rmse: 0.314402
# [114]	valid_0's rmse: 0.314423
# [115]	valid_0's rmse: 0.314421
# [116]	valid_0's rmse: 0.31444
# [117]	valid_0's rmse: 0.314462
# [118]	valid_0's rmse: 0.314483
# [119]	valid_0's rmse: 0.314422
# [120]	valid_0's rmse: 0.31441
# [121]	valid_0's rmse: 0.314439
# [122]	valid_0's rmse: 0.314397
# [123]	valid_0's rmse: 0.314444
# [124]	valid_0's rmse: 0.314489
# [125]	valid_0's rmse: 0.31445
# [126]	valid_0's rmse: 0.314401
# [127]	valid_0's rmse: 0.314398
# [128]	valid_0's rmse: 0.314377
# [129]	valid_0's rmse: 0.314318
# [130]	valid_0's rmse: 0.314335
# [131]	valid_0's rmse: 0.314292
# [132]	valid_0's rmse: 0.31433
# [133]	valid_0's rmse: 0.314349
# [134]	valid_0's rmse: 0.314373
# [135]	valid_0's rmse: 0.314355
# [136]	valid_0's rmse: 0.314397
# [137]	valid_0's rmse: 0.314392
# [138]	valid_0's rmse: 0.314434
# [139]	valid_0's rmse: 0.314465
# [140]	valid_0's rmse: 0.314456
# [141]	valid_0's rmse: 0.314438
# [142]	valid_0's rmse: 0.314472
# [143]	valid_0's rmse: 0.3145
# [144]	valid_0's rmse: 0.314548
# [145]	valid_0's rmse: 0.314551
# [146]	valid_0's rmse: 0.314564
# [147]	valid_0's rmse: 0.314492
# [148]	valid_0's rmse: 0.314518
# [149]	valid_0's rmse: 0.314583
# [150]	valid_0's rmse: 0.314598
# [151]	valid_0's rmse: 0.314565
# [152]	valid_0's rmse: 0.314544
# [153]	valid_0's rmse: 0.314529
# [154]	valid_0's rmse: 0.314488
# [155]	valid_0's rmse: 0.314499
# [156]	valid_0's rmse: 0.314496
# [157]	valid_0's rmse: 0.314474
# [158]	valid_0's rmse: 0.314439
# [159]	valid_0's rmse: 0.314432
# [160]	valid_0's rmse: 0.314463
# [161]	valid_0's rmse: 0.314511
# [162]	valid_0's rmse: 0.314513
# [163]	valid_0's rmse: 0.314536
# [164]	valid_0's rmse: 0.314504
# [165]	valid_0's rmse: 0.314507
# [166]	valid_0's rmse: 0.314535
# [167]	valid_0's rmse: 0.314491
# [168]	valid_0's rmse: 0.314484
# [169]	valid_0's rmse: 0.314452
# [170]	valid_0's rmse: 0.314443
# [171]	valid_0's rmse: 0.314432
# [172]	valid_0's rmse: 0.31446
# [173]	valid_0's rmse: 0.314504
# [174]	valid_0's rmse: 0.31449
# [175]	valid_0's rmse: 0.31446
# [176]	valid_0's rmse: 0.314455
# [177]	valid_0's rmse: 0.314468
# [178]	valid_0's rmse: 0.31449
# [179]	valid_0's rmse: 0.314508
# [180]	valid_0's rmse: 0.314535
# [181]	valid_0's rmse: 0.31449
# [182]	valid_0's rmse: 0.314504
# [183]	valid_0's rmse: 0.314482
# [184]	valid_0's rmse: 0.314486
# [185]	valid_0's rmse: 0.31447
# [186]	valid_0's rmse: 0.314446
# [187]	valid_0's rmse: 0.314465
# [188]	valid_0's rmse: 0.314477
# [189]	valid_0's rmse: 0.314492
# [190]	valid_0's rmse: 0.314496
# [191]	valid_0's rmse: 0.314484
# [192]	valid_0's rmse: 0.314476
# [193]	valid_0's rmse: 0.314473
# [194]	valid_0's rmse: 0.314496
# [195]	valid_0's rmse: 0.314506
# [196]	valid_0's rmse: 0.314488
# [197]	valid_0's rmse: 0.314483
# [198]	valid_0's rmse: 0.314453
# [199]	valid_0's rmse: 0.314446
# [200]	valid_0's rmse: 0.314465
# [201]	valid_0's rmse: 0.3145
# [202]	valid_0's rmse: 0.314501
# [203]	valid_0's rmse: 0.314519
# [204]	valid_0's rmse: 0.314509
# [205]	valid_0's rmse: 0.314575
# [206]	valid_0's rmse: 0.314613
# [207]	valid_0's rmse: 0.314603
# [208]	valid_0's rmse: 0.314609
# [209]	valid_0's rmse: 0.314615
# [210]	valid_0's rmse: 0.314594
# [211]	valid_0's rmse: 0.314583
# [212]	valid_0's rmse: 0.314594
# [213]	valid_0's rmse: 0.314579
# [214]	valid_0's rmse: 0.314514
# [215]	valid_0's rmse: 0.314467
# [216]	valid_0's rmse: 0.31448
# [217]	valid_0's rmse: 0.314508
# [218]	valid_0's rmse: 0.314478
# [219]	valid_0's rmse: 0.314504
# [220]	valid_0's rmse: 0.31451
# [221]	valid_0's rmse: 0.314564
# [222]	valid_0's rmse: 0.314546
# [223]	valid_0's rmse: 0.314505
# [224]	valid_0's rmse: 0.314492
# [225]	valid_0's rmse: 0.314499
# [226]	valid_0's rmse: 0.314516
# [227]	valid_0's rmse: 0.314509
# [228]	valid_0's rmse: 0.314508
# [229]	valid_0's rmse: 0.314566
# [230]	valid_0's rmse: 0.314566
# [231]	valid_0's rmse: 0.314547
# Early stopping, best iteration is:
# [131]	valid_0's rmse: 0.314292
# 100%|██████████| 20/20 [01:18<00:00,  3.94s/trial, best loss: 0.09848139922567092]

# %%
RMSE = lightgbm_factory(best)
print('best :', best)
print('best param after transform :')
argsDict_tranform(best,isPrint=True)
print('rmse of the best lightgbm:', np.sqrt(RMSE))
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000374 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 874
# [LightGBM] [Info] Number of data points in the train set: 7000, number of used features: 25
# [LightGBM] [Info] Start training from score 0.202286
# [1]	valid_0's rmse: 0.399284
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's rmse: 0.393957
# [3]	valid_0's rmse: 0.389614
# [4]	valid_0's rmse: 0.383487
# [5]	valid_0's rmse: 0.377345
# [6]	valid_0's rmse: 0.37403
# [7]	valid_0's rmse: 0.370073
# [8]	valid_0's rmse: 0.365062
# [9]	valid_0's rmse: 0.361843
# [10]	valid_0's rmse: 0.357601
# [11]	valid_0's rmse: 0.354844
# [12]	valid_0's rmse: 0.35136
# [13]	valid_0's rmse: 0.349163
# [14]	valid_0's rmse: 0.34621
# [15]	valid_0's rmse: 0.344128
# [16]	valid_0's rmse: 0.34161
# [17]	valid_0's rmse: 0.339826
# [18]	valid_0's rmse: 0.339195
# [19]	valid_0's rmse: 0.337617
# [20]	valid_0's rmse: 0.336487
# [21]	valid_0's rmse: 0.334794
# [22]	valid_0's rmse: 0.333503
# [23]	valid_0's rmse: 0.33189
# [24]	valid_0's rmse: 0.330713
# [25]	valid_0's rmse: 0.3294
# [26]	valid_0's rmse: 0.328224
# [27]	valid_0's rmse: 0.327874
# [28]	valid_0's rmse: 0.326789
# [29]	valid_0's rmse: 0.325781
# [30]	valid_0's rmse: 0.325053
# [31]	valid_0's rmse: 0.324105
# [32]	valid_0's rmse: 0.323508
# [33]	valid_0's rmse: 0.322984
# [34]	valid_0's rmse: 0.322637
# [35]	valid_0's rmse: 0.322015
# [36]	valid_0's rmse: 0.321456
# [37]	valid_0's rmse: 0.320955
# [38]	valid_0's rmse: 0.320507
# [39]	valid_0's rmse: 0.320175
# [40]	valid_0's rmse: 0.319812
# [41]	valid_0's rmse: 0.319332
# [42]	valid_0's rmse: 0.319117
# [43]	valid_0's rmse: 0.318717
# [44]	valid_0's rmse: 0.318442
# [45]	valid_0's rmse: 0.31814
# [46]	valid_0's rmse: 0.317793
# [47]	valid_0's rmse: 0.317652
# [48]	valid_0's rmse: 0.317292
# [49]	valid_0's rmse: 0.317112
# [50]	valid_0's rmse: 0.316953
# [51]	valid_0's rmse: 0.31685
# [52]	valid_0's rmse: 0.316577
# [53]	valid_0's rmse: 0.316486
# [54]	valid_0's rmse: 0.316326
# [55]	valid_0's rmse: 0.316143
# [56]	valid_0's rmse: 0.316124
# [57]	valid_0's rmse: 0.31596
# [58]	valid_0's rmse: 0.315871
# [59]	valid_0's rmse: 0.315806
# [60]	valid_0's rmse: 0.315702
# [61]	valid_0's rmse: 0.315575
# [62]	valid_0's rmse: 0.315507
# [63]	valid_0's rmse: 0.315541
# [64]	valid_0's rmse: 0.315495
# [65]	valid_0's rmse: 0.315355
# [66]	valid_0's rmse: 0.315242
# [67]	valid_0's rmse: 0.315047
# [68]	valid_0's rmse: 0.314988
# [69]	valid_0's rmse: 0.314782
# [70]	valid_0's rmse: 0.314698
# [71]	valid_0's rmse: 0.314534
# [72]	valid_0's rmse: 0.314535
# [73]	valid_0's rmse: 0.314449
# [74]	valid_0's rmse: 0.314285
# [75]	valid_0's rmse: 0.314316
# [76]	valid_0's rmse: 0.314409
# [77]	valid_0's rmse: 0.314396
# [78]	valid_0's rmse: 0.314366
# [79]	valid_0's rmse: 0.314322
# [80]	valid_0's rmse: 0.314237
# [81]	valid_0's rmse: 0.314262
# [82]	valid_0's rmse: 0.314226
# [83]	valid_0's rmse: 0.314193
# [84]	valid_0's rmse: 0.314117
# [85]	valid_0's rmse: 0.314112
# [86]	valid_0's rmse: 0.314124
# [87]	valid_0's rmse: 0.314128
# [88]	valid_0's rmse: 0.314082
# [89]	valid_0's rmse: 0.314039
# [90]	valid_0's rmse: 0.314047
# [91]	valid_0's rmse: 0.313935
# [92]	valid_0's rmse: 0.313975
# [93]	valid_0's rmse: 0.314022
# [94]	valid_0's rmse: 0.313924
# [95]	valid_0's rmse: 0.313912
# [96]	valid_0's rmse: 0.313891
# [97]	valid_0's rmse: 0.313906
# [98]	valid_0's rmse: 0.313981
# [99]	valid_0's rmse: 0.313952
# [100]	valid_0's rmse: 0.313969
# [101]	valid_0's rmse: 0.313877
# [102]	valid_0's rmse: 0.313817
# [103]	valid_0's rmse: 0.31385
# [104]	valid_0's rmse: 0.313876
# [105]	valid_0's rmse: 0.31388
# [106]	valid_0's rmse: 0.313876
# [107]	valid_0's rmse: 0.313931
# [108]	valid_0's rmse: 0.313964
# [109]	valid_0's rmse: 0.313986
# [110]	valid_0's rmse: 0.313956
# [111]	valid_0's rmse: 0.31397
# [112]	valid_0's rmse: 0.313983
# [113]	valid_0's rmse: 0.313937
# [114]	valid_0's rmse: 0.313963
# [115]	valid_0's rmse: 0.313893
# [116]	valid_0's rmse: 0.313888
# [117]	valid_0's rmse: 0.313967
# [118]	valid_0's rmse: 0.313924
# [119]	valid_0's rmse: 0.313902
# [120]	valid_0's rmse: 0.313879
# [121]	valid_0's rmse: 0.313955
# [122]	valid_0's rmse: 0.313939
# [123]	valid_0's rmse: 0.313944
# [124]	valid_0's rmse: 0.313958
# [125]	valid_0's rmse: 0.313959
# [126]	valid_0's rmse: 0.313951
# [127]	valid_0's rmse: 0.313964
# [128]	valid_0's rmse: 0.313982
# [129]	valid_0's rmse: 0.31398
# [130]	valid_0's rmse: 0.313932
# [131]	valid_0's rmse: 0.313903
# [132]	valid_0's rmse: 0.313912
# [133]	valid_0's rmse: 0.313887
# [134]	valid_0's rmse: 0.313873
# [135]	valid_0's rmse: 0.313914
# [136]	valid_0's rmse: 0.313954
# [137]	valid_0's rmse: 0.314007
# [138]	valid_0's rmse: 0.313998
# [139]	valid_0's rmse: 0.313998
# [140]	valid_0's rmse: 0.313982
# [141]	valid_0's rmse: 0.313976
# [142]	valid_0's rmse: 0.313995
# [143]	valid_0's rmse: 0.314032
# [144]	valid_0's rmse: 0.314042
# [145]	valid_0's rmse: 0.314024
# [146]	valid_0's rmse: 0.314038
# [147]	valid_0's rmse: 0.314029
# [148]	valid_0's rmse: 0.314055
# [149]	valid_0's rmse: 0.314068
# [150]	valid_0's rmse: 0.314107
# [151]	valid_0's rmse: 0.314129
# [152]	valid_0's rmse: 0.314116
# [153]	valid_0's rmse: 0.314097
# [154]	valid_0's rmse: 0.314011
# [155]	valid_0's rmse: 0.313985
# [156]	valid_0's rmse: 0.313871
# [157]	valid_0's rmse: 0.313919
# [158]	valid_0's rmse: 0.313928
# [159]	valid_0's rmse: 0.313889
# [160]	valid_0's rmse: 0.3139
# [161]	valid_0's rmse: 0.313839
# [162]	valid_0's rmse: 0.313871
# [163]	valid_0's rmse: 0.31389
# [164]	valid_0's rmse: 0.313916
# [165]	valid_0's rmse: 0.313937
# [166]	valid_0's rmse: 0.313895
# [167]	valid_0's rmse: 0.313921
# [168]	valid_0's rmse: 0.313929
# [169]	valid_0's rmse: 0.313975
# [170]	valid_0's rmse: 0.313944
# [171]	valid_0's rmse: 0.313891
# [172]	valid_0's rmse: 0.313937
# [173]	valid_0's rmse: 0.31391
# [174]	valid_0's rmse: 0.313902
# [175]	valid_0's rmse: 0.313903
# [176]	valid_0's rmse: 0.313901
# [177]	valid_0's rmse: 0.313954
# [178]	valid_0's rmse: 0.313941
# [179]	valid_0's rmse: 0.313938
# [180]	valid_0's rmse: 0.313937
# [181]	valid_0's rmse: 0.313955
# [182]	valid_0's rmse: 0.31395
# [183]	valid_0's rmse: 0.313943
# [184]	valid_0's rmse: 0.313965
# [185]	valid_0's rmse: 0.313979
# [186]	valid_0's rmse: 0.314009
# [187]	valid_0's rmse: 0.314017
# [188]	valid_0's rmse: 0.314005
# [189]	valid_0's rmse: 0.314007
# [190]	valid_0's rmse: 0.313962
# [191]	valid_0's rmse: 0.31399
# [192]	valid_0's rmse: 0.314012
# [193]	valid_0's rmse: 0.31406
# [194]	valid_0's rmse: 0.314055
# [195]	valid_0's rmse: 0.314074
# [196]	valid_0's rmse: 0.314038
# [197]	valid_0's rmse: 0.314024
# [198]	valid_0's rmse: 0.314058
# [199]	valid_0's rmse: 0.314
# [200]	valid_0's rmse: 0.31401
# [201]	valid_0's rmse: 0.31396
# [202]	valid_0's rmse: 0.31394
# Early stopping, best iteration is:
# [102]	valid_0's rmse: 0.313817
# best : {'bagging_fraction': 0.5, 'learning_rate': 0.059837710940647326, 'max_depth': 12, 'num_leaves': 13, 'num_trees': 252}
# best param after transform :
# {'bagging_fraction': 0.55, 'learning_rate': 0.05119675421881295, 'max_depth': 17, 'num_leaves': 49, 'num_trees': 402}
# rmse of the best lightgbm: 0.31381746163282714

# %%
mod = LGBMClassifier(**best)

# %%
pip1 = make_pipeline(feats, mod)

# %%
pip1.fit(X_train, y_train)
# Out:
# [LightGBM] [Warning] bagging_fraction is set=0.55, subsample=1.0 will be ignored. Current value: bagging_fraction=0.55
# [LightGBM] [Warning] num_iterations is set=402, num_trees=402 will be ignored. Current value: num_iterations=402
# Pipeline(steps=[('featureunion',
#                  FeatureUnion(transformer_list=[('Geography',
#                                                  Pipeline(steps=[('selector',
#                                                                   FeatureSelector(column='Geography')),
#                                                                  ('ohe',
#                                                                   OHEEncoder(key='Geography'))])),
#                                                 ('Gender',
#                                                  Pipeline(steps=[('selector',
#                                                                   FeatureSelector(column='Gender')),
#                                                                  ('ohe',
#                                                                   OHEEncoder(key='Gender'))])),
#                                                 ('Tenure',
#                                                  Pipeline(steps=[('selector',
#                                                                   FeatureSelector(column='...
#                                                 ('NumOfProducts',
#                                                  Pipeline(steps=[('selector',
#                                                                   NumberSelector(key='NumOfProducts')),
#                                                                  ('scaler',
#                                                                   StandardScaler())])),
#                                                 ('EstimatedSalary',
#                                                  Pipeline(steps=[('selector',
#                                                                   NumberSelector(key='EstimatedSalary')),
#                                                                  ('scaler',
#                                                                   StandardScaler())]))])),
#                 ('lgbmclassifier',
#                  LGBMClassifier(bagging_fraction=0.55,
#                                 learning_rate=0.05119675421881295, max_depth=17,
#                                 num_leaves=49, num_trees=402))])

# %%
y_pred = pip1.predict_proba(X_test)[:, 1]

thr, f1, pr, rec, roc = f_score(y_test.values, y_pred, b=1)
tn, fp, fn, tp = confusion_matrix(y_test.values, y_pred > thr).ravel()
fpr = fp / (fp + tn)

n_met = [thr, f1, pr, rec, roc, tp, tn, fp, fn, fpr]

# %%
result_df.append(pd.Series({i: j for i, j in zip(m_cols, n_met)}, name='lgbm(optimized)'))
# Out:
#                             Threshhold   F-score  Precision    Recall  \
# logisticregression            0.307705  0.488208   0.469388  0.508600
# randomforestclassifier        0.410000  0.600277   0.686709  0.533170
# gradientboostingclassifier    0.359124  0.611549   0.656338  0.572482
# lgbmclassifier                0.367175  0.621554   0.634271  0.609337
# xgbclassifier                 0.316108  0.600715   0.583333  0.619165
# lgbm(optimized)               0.225072  0.609566   0.556911  0.673219
#
#                              ROC-AUC     TP      TN     FP     FN       FPR
# logisticregression          0.750519  206.0  1359.0  234.0  201.0  0.146893
# randomforestclassifier      0.834033  211.0  1499.0   94.0  196.0  0.059008
# gradientboostingclassifier  0.851091  232.0  1471.0  122.0  175.0  0.076585
# lgbmclassifier              0.851255  247.0  1450.0  143.0  160.0  0.089768
# xgbclassifier               0.835745  251.0  1413.0  180.0  156.0  0.112994
# lgbm(optimized)             0.845127  273.0  1375.0  218.0  134.0  0.136849

# %% [markdown]
# Оценим работу оптимизированной модели на отложенной выборке

# %%
valid_pred = pip1.predict_proba(x_cv)[:, 1]

# %%
thr, f1, pr, rec, roc = f_score(y_cv.values, valid_pred, b=1)
tn, fp, fn, tp = confusion_matrix(y_cv.values, valid_pred > thr).ravel()
fpr = fp / (fp + tn)
n_met = [thr, f1, pr, rec, roc, tp, tn, fp, fn, fpr]

# %%
pd.Series({i: j for i, j in zip(m_cols, n_met)}, name='lgbm(optimized on holdout)')
# Out:
# Threshhold       0.263558
# F-score          0.603865
# Precision        0.581395
# Recall           0.628141
# ROC-AUC          0.838297
# TP             249.000000
# TN            1422.000000
# FP             180.000000
# FN             149.000000
# FPR              0.112360
# Name: lgbm(optimized on holdout), dtype: float64

# %% [markdown]
# Можно сделать вывод что наш вариант оптимизации особой пользы не принес

# %% [markdown]
# Посчитаем экономику

# %%
hold = -1
true_p = 2

tp * true_p + fp * 0 + (fn * hold + fn * true_p) + tn * hold
# Out:
# -775

# %% [markdown]
# Модель не целесообразна экономически (хотя незначительное улучшение мы все таки получили)
